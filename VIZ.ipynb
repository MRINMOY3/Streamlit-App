# %%
import numpy as np
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tip = sns.load_dataset('tips')

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tip.isna()
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
tip.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
## No null values are there 
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd

# %%
pd.set_option('display.min_rows',10)

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
pd.options.display.max_columns
# Out:
# 20

# %%
pd.set_option('display.max_columns',100)

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.T
# Out:
#                0       1       2       3       4       5       6       7    \
# total_bill   16.99   10.34   21.01   23.68   24.59   25.29    8.77   26.88
# tip           1.01    1.66     3.5    3.31    3.61    4.71     2.0    3.12
# sex         Female    Male    Male    Male  Female    Male    Male    Male
# smoker          No      No      No      No      No      No      No      No
# day            Sun     Sun     Sun     Sun     Sun     Sun     Sun     Sun
# time        Dinner  Dinner  Dinner  Dinner  Dinner  Dinner  Dinner  Dinner
# size             2       3       3       2       4       4       2       4
#
#                8       9       10      11      12      13      14      15   \
# total_bill   15.04   14.78   10.27   35.26   15.42   18.43   14.83   21.58
# tip           1.96    3.23    1.71     5.0    1.57     3.0    3.02    3.92
# sex           Male    Male    Male  Female    Male    Male  Female    Male
# ...

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Assume that thte avg bil of male is greater than that of female

## Sunday is ht ebusiest day of the week

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Report ing ->> Every part wee nedd to find the objective of the project
## Who gender 
## Who tips more 
## Time when more m=smokers came 


import numpy as np

# %%
import pandas as pd

# %%
corr = np.corrcoef(tip['total_bill'],tip['tip'])

# %%
print(corr)
# Out:
# [[1.         0.67573411]
#  [0.67573411 1.        ]]

# %%
## 1 rs -> in tip
## m-> -1 to +1 
## neg to pos ->> Positive correlaation
## To explain this we will use the scatter plots
import matplotlib.pyplot as plt

plt.plot(dpi = 100)
plt.scatter(tip['total_bill'],tip['tip'])
plt.xlabel('Total Bill')
plt.ylabel('Total Tip')
plt.show()

# %%
## Either regression line or other method 
## We will have the following
## The positive
## Higher ->> Strong correlation
## Lower  ->> Weak Relation


## Scatter Plot 
## Points we will have the following

#3 There is a positive ocrrelation between the two beacaause it is 0.67



plt.scatter(tip['tip'],tip['tip'])
plt.show()

# %%
## There is a hundred [ercent correlation]

# %%
tip.groupby('sex')[['total_bill','tip']].mean()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_28812\3184874357.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tip.groupby('sex')[['total_bill','tip']].mean()
#         total_bill       tip
# sex
# Male     20.744076  3.089618
# Female   18.056897  2.833448

# %%
gentip = tip.groupby('sex')[['total_bill','tip']].mean()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_28812\1948678958.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gentip = tip.groupby('sex')[['total_bill','tip']].mean()

# %%
plt.scatter(gentip,gentip)

# %%
sns.scatterplot('total_bill',data = tip)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 sns.scatterplot('total_bill',data = tip)
#       2 plt.show()
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Python312\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
TIP
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 TIP
#
# NameError: name 'TIP' is not defined

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.style.use('ggplot')
c = []

for value in tip['sex'].values:
    if value == 'Male':
        c.append('red')

    else:
        c.append('blue')

# %%
plt.plot(dpi=100)
plt.scatter(tip['total_bill'],tip['tip'],c=c)


## For the markinf scheme we will have tje follwing

plt.plot([],[],'ro',label='Male')

plt.plot([],[],'ko',label='Female',color = 'gray')




plt.legend()
plt.grid()

plt.show()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_28812\4123848082.py:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ko" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([],[],'ko',label='Female',color = 'gray')

# %%
##The other way round we will have the follwinf

sns.scatterplot('total_bill','tip',data = tip,hue='sex')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 ##The other way round we will have the follwinf
# ----> 3 sns.scatterplot('total_bill','tip',data = tip,hue='sex')
#       4 plt.show()
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %%
## Now we will have
size_dict = {'Sat':200,'Sun':150,'Mon':100,'Tue':50}
sns.scatterplot('total_bill','tip',data=tip,hue='sex',size='day')
s = [ size_dict.get(value)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 3
#       1 ## Now we will have
#       2 size_dict = {'Sat':200,'Sun':150,'Mon':100,'Tue':50}
# ----> 3 sns.scatterplot('total_bill','tip',data=tip,hue='sex',size='day')
#       4 s = [ size_dict.get(value)]
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %%
tip['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
size_dict = {'Sun':200,'Sat':150,'Thur':100,'Fri':50}

# %%
print(size_dict)
# Out:
# {'Sun': 200, 'Sat': 150, 'Thur': 100, 'Fri': 50}

# %%
s = [size_dict.get(value) for value in tip['day'].values]

# %%
plt.plot(dpi=100)
plt.scatter(tip['total_bill'],tip['tip'],c=c,s=s,marker='.')


## For the markinf scheme we will have tje follwing

plt.plot([],[],'ro',label='Male')

plt.plot([],[],'ko',label='Female',color = 'blue')




plt.legend()
plt.grid()

plt.show()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_28812\3079107323.py:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ko" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([],[],'ko',label='Female',color = 'blue')

# %%
plt.figure(dpi = 100)
sns.scatterplot('total_bill','tip',data = tip,hue='sex',size='day')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 2
#       1 plt.figure(dpi = 100)
# ----> 2 sns.scatterplot('total_bill','tip',data = tip,hue='sex',size='day')
#       3 plt.show()
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %%
tip.groupby('sex')[['total_bill','tip']].mean()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_28812\3184874357.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tip.groupby('sex')[['total_bill','tip']].mean()
#         total_bill       tip
# sex
# Male     20.744076  3.089618
# Female   18.056897  2.833448

# %%
d = tip.groupby('day')['day'].count()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_28812\2747712500.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   d = tip.groupby('day')['day'].count()

# %%
plt.bar(d.index,d.values,color=['r','g','b','c'])
# Out:
# <BarContainer object of 4 artists>

# %%
# sns.countplot(tip['day'],data=tip)
# plt.show()


plt.style.use('seaborn-notebook')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Python312\Lib\site-packages\matplotlib\style\core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File c:\Python312\Lib\site-packages\matplotlib\__init__.py:879, in _rc_params_in_file(fname, transform, fail_on_error)
#     878 rc_temp = {}
# --> 879 with _open_file_or_url(fname) as fd:
#     880     try:
#
# File c:\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File c:\Python312\Lib\site-packages\matplotlib\__init__.py:856, in _open_file_or_url(fname)
#     855 fname = os.path.expanduser(fname)
# --> 856 with open(fname, encoding='utf-8') as f:
#     857     yield f
#
# ...

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.head().T
# Out:
#                  0       1       2       3       4
# total_bill   16.99   10.34   21.01   23.68   24.59
# tip           1.01    1.66     3.5    3.31    3.61
# sex         Female    Male    Male    Male  Female
# smoker          No      No      No      No      No
# day            Sun     Sun     Sun     Sun     Sun
# time        Dinner  Dinner  Dinner  Dinner  Dinner
# size             2       3       3       2       4

# %%
flight = sns.load_dataset('flights')

# %%
flight.head().T
# Out:
#                0     1     2     3     4
# year        1949  1949  1949  1949  1949
# month        Jan   Feb   Mar   Apr   May
# passengers   112   118   132   129   121
